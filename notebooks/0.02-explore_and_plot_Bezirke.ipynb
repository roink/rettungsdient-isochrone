# %%
import geopandas as gpd
import folium
import sys
import os

# %%
sys.path.insert(0, os.path.abspath("../src"))
from plotting import plot_shapefile_with_labels

# %%
stadtbezirke_path = "../data/raw/Stadtbezirke_Hagen.shp"
gdf = gpd.read_file(stadtbezirke_path)
print(str(len(gdf)) + " Stadtbezirke")
gdf.head
# Out:
# 5 Stadtbezirke
# <bound method NDFrame.head of      BEZEICHNUN  Bez_Nr                                           geometry
# 0    Eilpe/Dahl       4  POLYGON ((395732.982 5686017.087, 395728.217 5...
# 1  Hohenlimburg       3  POLYGON ((394838.326 5693283.886, 394838.491 5...
# 2         Haspe       5  POLYGON ((391269.19 5686141.289, 391266.245 56...
# 3   Hagen-Mitte       1  POLYGON ((394838.326 5693283.886, 394843.321 5...
# 4    Hagen-Nord       2  POLYGON ((391409.509 5694737.638, 391412.948 5...>

# %%
statistische_bezirke_path = "../data/raw/Statistische_Bezirke_Hagen.shp"
gdf = gpd.read_file(statistische_bezirke_path)
print(str(len(gdf)) + " Statistische_Bezirke")
gdf.head
# Out:
# 13 Statistische_Bezirke
# <bound method NDFrame.head of           BEZEICHNUN  CNT_STATIS  STATISTICS  \
# 0              Boele          48       207.0
# 1           Lennetal          28       308.0
# 2          Haspe-Ost          23       512.0
# 3   Hochschulviertel          16       103.0
# 4      Wehringhausen          12       105.0
# 5               Emst          14       104.0
# 6       Hohenlimburg          34       309.0
# 7           Vorhalle          19       206.0
# 8         Haspe-West          13       513.0
# 9              Eilpe          21       410.0
# 10              Dahl          20       411.0
# 11       Mittelstadt          15       101.0
# 12        Altenhagen          23       102.0
#
#                                              geometry
# 0   POLYGON ((395264.584 5693752.076, 395263.846 5...
# 1   POLYGON ((396462.76 5691990.316, 396456.1 5691...
# 2   POLYGON ((391158.456 5691232.657, 391158.257 5...
# 3   POLYGON ((396026.692 5691041.234, 396002.975 5...
# 4   POLYGON ((393170.247 5690535.876, 393180.698 5...
# 5   POLYGON ((395319.838 5691100.706, 395409.665 5...
# 6   POLYGON ((400936.231 5685971.415, 400936.328 5...
# 7   POLYGON ((392656.6 5693117.077, 392660.003 569...
# 8   POLYGON ((389246.211 5687804.635, 389233.579 5...
# 9   POLYGON ((394386.306 5689705.257, 394391.479 5...
# 10  POLYGON ((395388.649 5683762.393, 395392.756 5...
# 11  POLYGON ((394486.053 5690028.317, 394477.081 5...
# 12  POLYGON ((393461.281 5691315.337, 393456.909 5...  >

# %%
wohnbezirke_path = "../data/raw/Wohnbezirke_Hagen.shp"
gdf = gpd.read_file(wohnbezirke_path)
print(str(len(gdf)) + " Wohnbezirke")
gdf.head
# Out:
# 39 Wohnbezirke
# <bound method NDFrame.head of                         NAME  NUMMER  \
# 0             Altenhagen-Süd   10203
# 1         Wehringhausen-West   10511
# 2                 Holthausen   30924
# 3                    Remberg   10102
# 4                  Emst-West   10409
# 5                 Elsey-Nord   30925
# 6                Eckesey-Süd   10204
# 7           Westerbauer-Nord   51338
# 8                Eppenhausen   10307
# 9                 Eilpe-Nord   41029
# 10           Westerbauer-Süd   51339
# 11                 Elsey-Süd   30926
# 12                   Zentrum   10101
# 13              Vorhalle-Süd   20615
# 14                Kuhlerkamp   10510
# 15                Spielbrink   51337
# 16                   Berchum   30821
# 17            Geweke/Tücking   51234
# 18             Fleyerviertel   10306
# 19             Haspe-Zentrum   51235
# 20        Eilpe-Süd/Selbecke   41030
# 21            Henkhausen/Reh   30923
# 22                Fley/Helfe   20719
# 23              Eckesey-Nord   20613
# 24               Oege/Nahmer   30928
# 25                  Delstern   41031
# 26         Wehringhausen-Ost   10512
# 27                 Garenfeld   20720
# 28                  Emst-Ost   10408
# 29              Kabel/Bathey   20718
# 30  Hlbg.-Zentrum/Wesselbach   30927
# 31           Altenhagen-Nord   10205
# 32             Vorhalle-Nord   20614
# 33         Priorei/Rummenohl   41133
# 34             Boele-Zentrum   20717
# 35               Boelerheide   20716
# 36                 Haspe-Süd   51236
# 37            Halden/Herbeck   30822
# 38                      Dahl   41132
#
#                                              geometry
# 0   POLYGON ((393969.235 5691656.712, 393980.252 5...
# 1   POLYGON ((392974.578 5689256.317, 393043.016 5...
# 2   POLYGON ((398631.142 5688732.327, 398646.915 5...
# 3   POLYGON ((394034.358 5691585.515, 394049.645 5...
# 4   POLYGON ((395858.822 5689487.91, 395850.046 56...
# 5   POLYGON ((398822.839 5691875.075, 398831.086 5...
# 6   POLYGON ((392656.6 5693117.077, 392789.92 5693...
# 7   POLYGON ((387347.865 5688642.66, 387353.816 56...
# 8   POLYGON ((395896.737 5692472.679, 395912.624 5...
# 9   POLYGON ((394051.939 5689968.536, 394067.844 5...
# 10  POLYGON ((389389.849 5689175.396, 389396.497 5...
# 11  POLYGON ((401722.196 5690877.452, 401719.236 5...
# 12  POLYGON ((394477.081 5690035.189, 394476.009 5...
# 13  POLYGON ((392162.691 5692978.227, 392152.566 5...
# 14  POLYGON ((391162.003 5691755.629, 391174.445 5...
# 15  POLYGON ((388195.394 5691353.326, 388219.111 5...
# 16  POLYGON ((397210.434 5694039.588, 397211.48 56...
# 17  POLYGON ((389384.708 5691499.718, 389386.072 5...
# 18  POLYGON ((395537.597 5692797.021, 395540.273 5...
# 19  POLYGON ((391643.241 5690393.772, 391662.037 5...
# 20  POLYGON ((395825.983 5686307.345, 395824.342 5...
# 21  POLYGON ((398822.839 5691875.075, 398805.345 5...
# 22  POLYGON ((395934.523 5694329.96, 395924.748 56...
# 23  POLYGON ((392545.581 5693447.276, 392558.028 5...
# 24  POLYGON ((401027.182 5683721.292, 400960.709 5...
# 25  POLYGON ((395374.727 5689600.776, 395406.93 56...
# 26  POLYGON ((392974.578 5689256.317, 392960.916 5...
# 27  POLYGON ((396672.457 5694636.747, 396672.451 5...
# 28  POLYGON ((398117.861 5689852.392, 398115.261 5...
# 29  POLYGON ((395197.04 5697140.899, 395197.044 56...
# 30  POLYGON ((398549.658 5687717.227, 398549.764 5...
# 31  POLYGON ((394831.782 5693273.141, 394832.243 5...
# 32  POLYGON ((391409.786 5694740.369, 391409.509 5...
# 33  POLYGON ((400153.526 5682931.588, 400143.03 56...
# 34  POLYGON ((392368.463 5693843.711, 392357.512 5...
# 35  POLYGON ((393351.294 5692954.081, 393269.396 5...
# 36  POLYGON ((391605.047 5687418.974, 391602.78 56...
# 37  POLYGON ((394831.782 5693273.141, 394838.291 5...
# 38  POLYGON ((395732.704 5686014.031, 395732.982 5...  >

# %%
def calculate_center_from_shapefile(shapefile_path: str):
    # Load the shapefile using geopandas
    gdf = gpd.read_file(shapefile_path)
    
    # Reproject to WGS84 if necessary
    if gdf.crs != "EPSG:4326":
        gdf = gdf.to_crs(epsg=4326)
    
    # Get the bounding box (minx, miny, maxx, maxy)
    minx, miny, maxx, maxy = gdf.total_bounds
    print(minx, miny, maxx, maxy)
    # Calculate the center coordinates
    center_x = (minx + maxx) / 2
    center_y = (miny + maxy) / 2
    
    return center_y, center_x  # Return in folium's expected (lat, lon) order

# %%
map_location = calculate_center_from_shapefile(stadtbezirke_path)  # Coordinates to center the map on
map_location
# Out:
# 7.37586644151297 51.264836728429444 7.598894722085717 51.41859378414624
# (np.float64(51.34171525628784), np.float64(7.487380581799344))

# %%
stadtbezirke_map = plot_shapefile_with_labels(stadtbezirke_path, map_location,name_column="BEZEICHNUN")

# Save the map
stadtbezirke_map.save("../reports/figures/Stadtbezirke_Hagen.html")
stadtbezirke_map
# Out:
# Reprojecting from EPSG:25832 to WGS84 (EPSG:4326)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccc5a5a1ae33687f226448d4c5443a1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccc5a5a1ae33687f226448d4c5443a1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccc5a5a1ae33687f226448d4c5443a1e = L.map(
#                 &quot;map_ccc5a5a1ae33687f226448d4c5443a1e&quot;,
#                 {
#                     center: [51.34171525628784, 7.487380581799344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3889dfb2bc1032108854056ab17677d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3889dfb2bc1032108854056ab17677d4.addTo(map_ccc5a5a1ae33687f226448d4c5443a1e);
#
#
#
#         function geo_json_8802a8b6ca65448c7a118f182d3abfac_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8802a8b6ca65448c7a118f182d3abfac = L.geoJson(null, {
#                 onEachFeature: geo_json_8802a8b6ca65448c7a118f182d3abfac_onEachFeature,
#
#         });
#
#         function geo_json_8802a8b6ca65448c7a118f182d3abfac_add (data) {
#             geo_json_8802a8b6ca65448c7a118f182d3abfac
#                 .addData(data);
#         }
